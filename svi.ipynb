# %% [markdown]
# Looking into the CDC Social Vulnerability Index

# %%
#imports
import pandas as pd

# %%
#loading
df = pd.read_csv("/Users/pdeguz01/Documents/git/Data/IDS705_Final/SVI_2022_US_ZCTA.csv")

# %%
df["F_THEME4"].value_counts()
# Out:
# F_THEME4
#  0      20916
#  1       8465
#  2       2535
# -999      954
#  3        710
#  4         61
#  5          1
# Name: count, dtype: int64
